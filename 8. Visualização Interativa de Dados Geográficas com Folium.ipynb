# %% [markdown]
# ## Visualização Interativa de Dados Geográficos

# %% [markdown]
# # Folium
#
# * Documentação no GitHub - https://python-visualization.github.io/folium/latest/

# %%
import pandas as pd
import geopandas as gpd
import folium

# %%
# ler arquivos Countries
countries = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Ler arquivo Acled 
acled = gpd.read_file(
    r'C:\Users\iribarre\Downloads\5-+Interactive+Visualization\data\acled2019.shp',
    mask = countries[countries['continent'] == 'South America']
)

# %%
acled.head()
# Out:
#    data_id  iso event_id_c  event_id_n        event_date  year  time_preci  \
# 0  6947603   76   BRA10737       10737  31 December 2019  2019           2
# 1  6966548   76   BRA10732       10732  31 December 2019  2019           1
# 2  6938394  170    COL1824        1824  31 December 2019  2019           2
# 3  6953510   32    ARG1263        1263  31 December 2019  2019           1
# 4  6931761  152    CHI2724        2724  31 December 2019  2019           1
#
#                    event_type        sub_event_  \
# 0  Violence against civilians            Attack
# 1                     Battles       Armed clash
# 2      Strategic developments             Other
# 3                    Protests  Peaceful protest
# 4                    Protests  Peaceful protest
#
#                                               actor1  ... latitude  longitude  \
# 0            Unidentified Gang and/or Police Militia  ...  -8.0694   -37.2684
# 1  Military Forces of Brazil (2019-) Military Police  ...  -3.1019   -60.0250
# 2                Unidentified Armed Group (Colombia)  ...   7.7872   -75.5331
# 3                             Protesters (Argentina)  ... -31.9745   -60.9160
# 4                                 Protesters (Chile)  ... -41.4693   -72.9424
#
#   geo_precis                  source   source_sca  \
# 0          1                      G1     National
# 1          1       Portal do Holanda     National
# 2          2           El Espectador     National
# 3          1  La Capital (Argentina)  Subnational
# 4          1            Biobio Chile     National
#
#                                                notes fatalities   timestamp  \
# 0  On 30 December 2019, in Sertania, Pernambuco, ...          1  1582840217
# 1  On 31 December 2019, in Manaus, Amazonas, two ...          2  1582840367
# 2  As reported on December 31 2019, between La Ca...          0  1582839943
# 3  On 31 December 2019, in Coronda (Santa Fe), a ...          0  1582840236
# 4  On 31 December 2019, in Puerto Montt, Los Lago...          0  1582839796
#
#   iso3                     geometry
# 0  BRA   POINT (-37.26840 -8.06940)
# 1  BRA   POINT (-60.02500 -3.10190)
# 2  COL    POINT (-75.53310 7.78720)
# 3  ARG  POINT (-60.91600 -31.97450)
# 4  CHL  POINT (-72.94240 -41.46930)
#
# [5 rows x 32 columns]

# %%
# Use o folium para localizar uma coordanada no Map street Maps
m= folium.Map(location=[-23.6100596,-46.6973898])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a41259ce5bb2a18ac794ee4b644b7224 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a41259ce5bb2a18ac794ee4b644b7224&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a41259ce5bb2a18ac794ee4b644b7224 = L.map(
#                 &quot;map_a41259ce5bb2a18ac794ee4b644b7224&quot;,
#                 {
#                     center: [-23.6100596, -46.6973898],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3769de92f1f634b2919ba91b67dfdb64 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3769de92f1f634b2919ba91b67dfdb64.addTo(map_a41259ce5bb2a18ac794ee4b644b7224);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Visualização de um ponto específico no mapa

# %%
# Adicione zoom. Quanto menor o número, mais distante. 
m= folium.Map(location=[-23.6100596,-46.6973898], zoom_start=15)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35cdbfa276010ad1fe899e7fb8ee92ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35cdbfa276010ad1fe899e7fb8ee92ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35cdbfa276010ad1fe899e7fb8ee92ca = L.map(
#                 &quot;map_35cdbfa276010ad1fe899e7fb8ee92ca&quot;,
#                 {
#                     center: [-23.6100596, -46.6973898],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb5097ff0fe94ece83bf9d24cfc663ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fb5097ff0fe94ece83bf9d24cfc663ea.addTo(map_35cdbfa276010ad1fe899e7fb8ee92ca);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Mude a base do mapa
m= folium.Map(location=[-23.6100596,-46.6973898], tiles='CartoDB dark_matter', zoom_start=15)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb513a18493dc5e41b6b9f107f0af3d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb513a18493dc5e41b6b9f107f0af3d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb513a18493dc5e41b6b9f107f0af3d5 = L.map(
#                 &quot;map_fb513a18493dc5e41b6b9f107f0af3d5&quot;,
#                 {
#                     center: [-23.6100596, -46.6973898],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57ec75d3b934d52a6b5643b2745ec47a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_57ec75d3b934d52a6b5643b2745ec47a.addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Adicione um marcador na localização específica
folium.Marker(
    location=[-23.6100596,-46.6973898],
    radius=25,
    popup='Anfield Stadium',
    color='crimson',
    fill=True
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb513a18493dc5e41b6b9f107f0af3d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb513a18493dc5e41b6b9f107f0af3d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb513a18493dc5e41b6b9f107f0af3d5 = L.map(
#                 &quot;map_fb513a18493dc5e41b6b9f107f0af3d5&quot;,
#                 {
#                     center: [-23.6100596, -46.6973898],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57ec75d3b934d52a6b5643b2745ec47a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_57ec75d3b934d52a6b5643b2745ec47a.addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#             tile_layer_57ec75d3b934d52a6b5643b2745ec47a.addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#             var marker_9c95a9f5e84a4ee48adc38836840f376 = L.marker(
#                 [-23.6100596, -46.6973898],
#                 {&quot;color&quot;: &quot;crimson&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 25}
#             ).addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#         var popup_eedac0dedb04a496113f937258e43682 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1a49cc9ad1acaf950af2c097fbd7208 = $(`&lt;div id=&quot;html_f1a49cc9ad1acaf950af2c097fbd7208&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Anfield Stadium&lt;/div&gt;`)[0];
#                 popup_eedac0dedb04a496113f937258e43682.setContent(html_f1a49cc9ad1acaf950af2c097fbd7208);
#
#
#
#         marker_9c95a9f5e84a4ee48adc38836840f376.bindPopup(popup_eedac0dedb04a496113f937258e43682)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Adicione texto no marcador
folium.Marker(
    location=[-23.6100596,-46.6973898],
    popup='<i>HERE São Paulo</i>'
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb513a18493dc5e41b6b9f107f0af3d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb513a18493dc5e41b6b9f107f0af3d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb513a18493dc5e41b6b9f107f0af3d5 = L.map(
#                 &quot;map_fb513a18493dc5e41b6b9f107f0af3d5&quot;,
#                 {
#                     center: [-23.6100596, -46.6973898],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57ec75d3b934d52a6b5643b2745ec47a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_57ec75d3b934d52a6b5643b2745ec47a.addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#             tile_layer_57ec75d3b934d52a6b5643b2745ec47a.addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#             var marker_9c95a9f5e84a4ee48adc38836840f376 = L.marker(
#                 [-23.6100596, -46.6973898],
#                 {&quot;color&quot;: &quot;crimson&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 25}
#             ).addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#         var popup_eedac0dedb04a496113f937258e43682 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1a49cc9ad1acaf950af2c097fbd7208 = $(`&lt;div id=&quot;html_f1a49cc9ad1acaf950af2c097fbd7208&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Anfield Stadium&lt;/div&gt;`)[0];
#                 popup_eedac0dedb04a496113f937258e43682.setContent(html_f1a49cc9ad1acaf950af2c097fbd7208);
#
#
#
#         marker_9c95a9f5e84a4ee48adc38836840f376.bindPopup(popup_eedac0dedb04a496113f937258e43682)
#         ;
#
#
#
#
#             tile_layer_57ec75d3b934d52a6b5643b2745ec47a.addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#             var marker_1b3a12a59d2d930f891dd6180970cfdc = L.marker(
#                 [-23.6100596, -46.6973898],
#                 {}
#             ).addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#         var popup_78c0c0703e65f07f9fea7a79412ecfb4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3cae903d64ea98997c103ac81b900891 = $(`&lt;div id=&quot;html_3cae903d64ea98997c103ac81b900891&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;,Stanley Park&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_78c0c0703e65f07f9fea7a79412ecfb4.setContent(html_3cae903d64ea98997c103ac81b900891);
#
#
#
#         marker_1b3a12a59d2d930f891dd6180970cfdc.bindPopup(popup_78c0c0703e65f07f9fea7a79412ecfb4)
#         ;
#
#
#
#
#             tile_layer_57ec75d3b934d52a6b5643b2745ec47a.addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#             var marker_e0c0dc141aa05832f56f370192e66742 = L.marker(
#                 [-23.6100596, -46.6973898],
#                 {}
#             ).addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#         var popup_ebbf1cd50447af92ddf8b67a56f0fdd3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a12be96b818a28355347e11114e35a0f = $(`&lt;div id=&quot;html_a12be96b818a28355347e11114e35a0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;,Here São Paulo&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_ebbf1cd50447af92ddf8b67a56f0fdd3.setContent(html_a12be96b818a28355347e11114e35a0f);
#
#
#
#         marker_e0c0dc141aa05832f56f370192e66742.bindPopup(popup_ebbf1cd50447af92ddf8b67a56f0fdd3)
#         ;
#
#
#
#
#             tile_layer_57ec75d3b934d52a6b5643b2745ec47a.addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#             var marker_c750852cb816ca6d8d3c2d9ec1c292ba = L.marker(
#                 [-23.6100596, -46.6973898],
#                 {}
#             ).addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#         var popup_521742d68145e09b058c1d6b88c114a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24bcb01b2fb80dae474f6b2185374755 = $(`&lt;div id=&quot;html_24bcb01b2fb80dae474f6b2185374755&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;HERE São Paulo&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_521742d68145e09b058c1d6b88c114a7.setContent(html_24bcb01b2fb80dae474f6b2185374755);
#
#
#
#         marker_c750852cb816ca6d8d3c2d9ec1c292ba.bindPopup(popup_521742d68145e09b058c1d6b88c114a7)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Adicione um marcador em círculo
folium.Circle(
    location=[-23.6100596,-46.6973898], 
    radius=25,
    popup='HERE São Paulo',
    color='crimson', 
    fill=True,
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb513a18493dc5e41b6b9f107f0af3d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb513a18493dc5e41b6b9f107f0af3d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb513a18493dc5e41b6b9f107f0af3d5 = L.map(
#                 &quot;map_fb513a18493dc5e41b6b9f107f0af3d5&quot;,
#                 {
#                     center: [-23.6100596, -46.6973898],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57ec75d3b934d52a6b5643b2745ec47a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_57ec75d3b934d52a6b5643b2745ec47a.addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#             tile_layer_57ec75d3b934d52a6b5643b2745ec47a.addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#             var marker_9c95a9f5e84a4ee48adc38836840f376 = L.marker(
#                 [-23.6100596, -46.6973898],
#                 {&quot;color&quot;: &quot;crimson&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 25}
#             ).addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#         var popup_eedac0dedb04a496113f937258e43682 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1a49cc9ad1acaf950af2c097fbd7208 = $(`&lt;div id=&quot;html_f1a49cc9ad1acaf950af2c097fbd7208&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Anfield Stadium&lt;/div&gt;`)[0];
#                 popup_eedac0dedb04a496113f937258e43682.setContent(html_f1a49cc9ad1acaf950af2c097fbd7208);
#
#
#
#         marker_9c95a9f5e84a4ee48adc38836840f376.bindPopup(popup_eedac0dedb04a496113f937258e43682)
#         ;
#
#
#
#
#             tile_layer_57ec75d3b934d52a6b5643b2745ec47a.addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#             var marker_1b3a12a59d2d930f891dd6180970cfdc = L.marker(
#                 [-23.6100596, -46.6973898],
#                 {}
#             ).addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#         var popup_78c0c0703e65f07f9fea7a79412ecfb4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3cae903d64ea98997c103ac81b900891 = $(`&lt;div id=&quot;html_3cae903d64ea98997c103ac81b900891&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;,Stanley Park&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_78c0c0703e65f07f9fea7a79412ecfb4.setContent(html_3cae903d64ea98997c103ac81b900891);
#
#
#
#         marker_1b3a12a59d2d930f891dd6180970cfdc.bindPopup(popup_78c0c0703e65f07f9fea7a79412ecfb4)
#         ;
#
#
#
#
#             tile_layer_57ec75d3b934d52a6b5643b2745ec47a.addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#             var marker_e0c0dc141aa05832f56f370192e66742 = L.marker(
#                 [-23.6100596, -46.6973898],
#                 {}
#             ).addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#         var popup_ebbf1cd50447af92ddf8b67a56f0fdd3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a12be96b818a28355347e11114e35a0f = $(`&lt;div id=&quot;html_a12be96b818a28355347e11114e35a0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;,Here São Paulo&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_ebbf1cd50447af92ddf8b67a56f0fdd3.setContent(html_a12be96b818a28355347e11114e35a0f);
#
#
#
#         marker_e0c0dc141aa05832f56f370192e66742.bindPopup(popup_ebbf1cd50447af92ddf8b67a56f0fdd3)
#         ;
#
#
#
#
#             tile_layer_57ec75d3b934d52a6b5643b2745ec47a.addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#             var marker_c750852cb816ca6d8d3c2d9ec1c292ba = L.marker(
#                 [-23.6100596, -46.6973898],
#                 {}
#             ).addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#         var popup_521742d68145e09b058c1d6b88c114a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24bcb01b2fb80dae474f6b2185374755 = $(`&lt;div id=&quot;html_24bcb01b2fb80dae474f6b2185374755&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;HERE São Paulo&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_521742d68145e09b058c1d6b88c114a7.setContent(html_24bcb01b2fb80dae474f6b2185374755);
#
#
#
#         marker_c750852cb816ca6d8d3c2d9ec1c292ba.bindPopup(popup_521742d68145e09b058c1d6b88c114a7)
#         ;
#
#
#
#
#             tile_layer_57ec75d3b934d52a6b5643b2745ec47a.addTo(map_fb513a18493dc5e41b6b9f107f0af3d5);
#
#
#             var circle_206d174ec75f53684f5537af39b24089 = L.circle(
#                 [-23.6100596, -46.6973898],
#                 {&

# %% [markdown]
# Visualização do arquivo Acled

# %%
# Visualização direta a partir do geopandas/geojson
m = folium.Map([-23.6100596,-46.6973898], zoom_start=2, tites='cartodbpositron')
folium.GeoJson(acled.sample(1000)).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea580c8b2e6d3c03257cf2807d687455 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea580c8b2e6d3c03257cf2807d687455&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea580c8b2e6d3c03257cf2807d687455 = L.map(
#                 &quot;map_ea580c8b2e6d3c03257cf2807d687455&quot;,
#                 {
#                     center: [-23.6100596, -46.6973898],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     tites: &quot;cartodbpositron&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8eb7f4ce5039d8d0e3adc86be60b4249 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8eb7f4ce5039d8d0e3adc86be60b4249.addTo(map_ea580c8b2e6d3c03257cf2807d687455);
#
#
#
#         function geo_json_221469a9d1712df23af07a70844799d2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_221469a9d1712df23af07a70844799d2 = L.geoJson(null, {
#                 onEachFeature: geo_json_221469a9d1712df23af07a70844799d2_onEachFeature,
#
#         });
#
#         function geo_json_221469a9d1712df23af07a70844799d2_add (data) {
#             geo_json_221469a9d1712df23af07a70844799d2
#                 .addData(data);
#         }
#             geo_json_221469a9d1712df23af07a70844799d2_add({&quot;bbox&quot;: [-80.6833, -54.8062, -34.8631, 11.6378], &quot;features&quot;: [{&quot;bbox&quot;: [-43.3008, -22.8569, -43.3008, -22.8569], &quot;geometry&quot;: {&quot;coordinates&quot;: [-43.3008, -22.8569], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;20982&quot;, &quot;properties&quot;: {&quot;actor1&quot;: &quot;Unidentified Armed Group (Brazil)&quot;, &quot;actor2&quot;: &quot;Unidentified Armed Group (Brazil)&quot;, &quot;admin1&quot;: &quot;Rio de Janeiro&quot;, &quot;admin2&quot;: &quot;Rio de Janeiro&quot;, &quot;admin3&quot;: null, &quot;assoc_ac_1&quot;: null, &quot;assoc_acto&quot;: null, &quot;country&quot;: &quot;Brazil&quot;, &quot;data_id&quot;: 6964867, &quot;event_date&quot;: &quot;09 January 2019&quot;, &quot;event_id_c&quot;: &quot;BRA352&quot;, &quot;event_id_n&quot;: 352, &quot;event_type&quot;: &quot;Battles&quot;, &quot;fatalities&quot;: 0, &quot;geo_precis&quot;: 1, &quot;inter1&quot;: 3, &quot;inter2&quot;: 3, &quot;interactio&quot;: 33, &quot;iso&quot;: 76, &quot;iso3&quot;: &quot;BRA&quot;, &quot;latitude&quot;: -22.8569, &quot;location&quot;: &quot;Rio de Janeiro-North Zone&quot;, &quot;longitude&quot;: -43.3008, &quot;notes&quot;: &quot;On 9 Jan 2019, in Rio de Janeiro (RJ), it was reported through the application _nde Tem Tiroteio - RJ_that shoot-outs took place in Anchieta, in Engenho Novo, and in Ilha do Governador. No further information recorded.&quot;, &quot;region&quot;: &quot;South America&quot;, &quot;source&quot;: &quot;OTT-RJ&quot;, &quot;source_sca&quot;: &quot;New media&quot;, &quot;sub_event_&quot;: &quot;Armed clash&quot;, &quot;time_preci&quot;: 1, &quot;timestamp&quot;: 1582840347, &quot;year&quot;: 2019}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-40.8443, -14.8622, -40.8443, -14.8622], &quot;geometry&quot;: {&quot;coordinates&quot;: [-40.8443, -14.8622], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;13379&quot;, &quot;properties&quot;: {&quot;actor1&quot;: &quot;Protesters (Brazil)&quot;, &quot;actor2&quot;: null, &quot;admin1&quot;: &quot;Bahia&quot;, &quot;admin2&quot;: &quot;Vitoria da Conquista&quot;, &quot;admin3&quot;: null, &quot;assoc_ac_1&quot;: null, &quot;assoc_acto&quot;: &quot;PSL: Social Liberal Party&quot;, &quot;country&quot;: &quot;Brazil&quot;, &quot;data_id&quot;: 6949694, &quot;event_date&quot;: &quot;26 May 2019&quot;, &quot;event_id_c&quot;: &quot;BRA4717&quot;, &quot;event_id_n&quot;: 4717, &quot;event_type&quot;: &quot;Protests&quot;, &quot;fatalities&quot;: 0, &quot;geo_precis&quot;: 1, &quot;inter1&quot;: 6, &quot;inter2&quot;: 0, &quot;interactio&quot;: 60, &quot;iso&quot;: 76, &quot;iso3&quot;: &quot;BRA&quot;, &quot;latitude&quot;: -14.8622, &quot;location&quot;: &quot;Vitoria da Conquista&quot;, &quot;longitude&quot;: -40.8443, &quot;notes&quot;: &quot;On 26 May 2019, in Vitoria da Conquista, Bahia, a protest was held in favour of Jair Bolsonaro_ (PSL) Government. The protesters defended the proposals for ministerial and Social Security reforms and the anti-crime package. [size=no report]&quot;, &quot;region&quot;: &quot;South America&quot;, &quot;source&quot;: &quot;G1&quot;, &quot;source_sca&quot;: &quot;National&quot;, &quot;sub_event_&quot;: &quot;Peaceful protest&quot;, &quot;time_preci&quot;: 1, &quot;timestamp&quot;: 1582840224, &quot;year&quot;: 2019}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-71.6554, -35.4264, -71.6554, -35.4264], &quot;geometry&quot;: {&quot;coordinates&quot;: [-71.6554, -35.4264], &quot;type&quot;

# %%
m = folium.Map([-23.6100596,-46.6973898], zoom_start=2, titles='cartodbpositron')
acled_sample = acled.sample(100)
locs_points = zip(acled_sample.geometry.y, acled_sample.geometry.x)
for location in locs_points:
    folium.CircleMarker(location=location, color='red', radius=0.5).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_245870b2984bf55dcf26777217f2b032 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_245870b2984bf55dcf26777217f2b032&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_245870b2984bf55dcf26777217f2b032 = L.map(
#                 &quot;map_245870b2984bf55dcf26777217f2b032&quot;,
#                 {
#                     center: [-23.6100596, -46.6973898],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;cartodbpositron&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9c70c77604209976a071d12788e31d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b9c70c77604209976a071d12788e31d8.addTo(map_245870b2984bf55dcf26777217f2b032);
#
#
#             var circle_marker_447d186a00f06926be256e7c681fcddb = L.circleMarker(
#                 [-34.873000000000005, -57.8834],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_245870b2984bf55dcf26777217f2b032);
#
#
#             var circle_marker_2e67b2ce9a14d82cb47fffab77845b0b = L.circleMarker(
#                 [-20.4428, -54.6464],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_245870b2984bf55dcf26777217f2b032);
#
#
#             var circle_marker_2c78de314b1c9f8d1dbbb0102110574f = L.circleMarker(
#                 [0.505, -76.4973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_245870b2984bf55dcf26777217f2b032);
#
#
#             var circle_marker_e2998b063f4e60481b1b4b5b4e239f12 = L.circleMarker(
#                 [-16.4957, -68.1336],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_245870b2984bf55dcf26777217f2b032);
#
#
#             var circle_marker_f20073265a3763299fa0d8ab3f46cd8d = L.circleMarker(
#                 [-43.2527, -65.3062],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_245870b2984bf55dcf26777217f2b032);
#
#
#             var circle_marker_02c5d23bdcf321df91af089ddf98769d = L.circleMarker(
#                 [-3.7172, -38.5431],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_245870b2984bf55dcf26777217f2b032);
#
#
#             var circle_marker_75694b15311512d3539703556a0d9f85 = L.circleMarker(
#                 [-29.9045, -71.2

# %%
# Importe nova biblioteca
from folium.plugins import FastMarkerCluster 

# Visualizar map em cluster (conjunto)
cmap = folium.Map(location=[-23.6100596,-46.6973898],
                 zoom_start=2,
                  tiles='CartoDB dark_matter')

# Criação de um mapa de clusters a partir de uma lista de coordenadas, alterando a visualização de acordo com o zoom
FastMarkerCluster(data=list(zip(acled_sample.geometry.y.values, acled_sample.geometry.x.values))).add_to(cmap)
folium.LayerControl().add_to(cmap)
cmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0bc90e16c8ee860646fa1f7e0afbe53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0bc90e16c8ee860646fa1f7e0afbe53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0bc90e16c8ee860646fa1f7e0afbe53 = L.map(
#                 &quot;map_f0bc90e16c8ee860646fa1f7e0afbe53&quot;,
#                 {
#                     center: [-23.6100596, -46.6973898],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b016a4d6bb604f6887b543e92efb3c88 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b016a4d6bb604f6887b543e92efb3c88.addTo(map_f0bc90e16c8ee860646fa1f7e0afbe53);
#
#
#             var fast_marker_cluster_da5ee0b193b3a97b1447ef6ea182ae1c = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[8.4364, -73.2874], [7.1163, -73.1326], [-27.6352, -52.2729], [-30.0331, -51.23], [-22.9064, -43.1822], [1.4944, -78.0769], [-22.7856, -43.3117], [9.2155, -66.0073], [-25.4278, -49.2731], [-22.7825, -43.4286], [-41.3504, -71.5107], [7.2949, -75.3874], [-23.1794, -45.8869], [-11.0267, -68.7692], [10.5772, -62.2984], [-19.5836, -65.7531], [-5.3815, -49.1323], [-15.8422, -70.0199], [-3.7172, -38.5431], [-21.1261, -56.4902], [10.1728, -70.081], [-40.574, -73.1335], [-1.4558, -48.5044], [-6.7714, -79.8409], [-22.5361, -55.7256], [10.4863, -66.8081], [-22.9657, -43.1991], [-16.8367, -64.7932], [-29.2391, -51.8689], [-23.0067, -44.3181], [-33.4569, -70.6483], [-22.8569, -43.3008], [-38.7397, -72.5984], [8.5897, -71.1561], [-34.6132, -58.3772], [-22.9064, -43.1822], [-22.7642, -43.3994], [-25.4444, -56.4403], [-23.8317, -46.121], [10.4829, -66.9036], [-17.7863, -63.1812], [-17.4377, -67.5186], [-13.2582, -72.2639], [-1.3206, -78.5779], [10.4829, -66.9036], [-12.2299, -76.8593], [-16.4957, -68.1336], [-22.8833, -43.1036], [-9.6658, -35.7353], [-25.8, -57.2333], [-6.6447, -51.995], [7.3471, -61.8268], [-40.574, -73.1335], [-22.8833, -43.1036], [-20.2558, -69.7863], [9.5869, -74.8275], [-30.0331, -51.23], [-16.0706, -57.6789], [-34.9856, -71.2398], [7.2949, -75.3874], [8.3217, -73.146], [-38.0156, -73.2299], [-11.0147, -37.2064], [-17.7481, -48.6271], [10.5008, -66.8536], [5.0577, -75.4911], [-8.2833, -35.9761], [-20.4428, -54.6464], [-38.5307, -72.4365], [-29.1714, -51.5192], [1.1172, -76.3258], [10.4829, -66.9036], [-22.8569, -43.3008], [-25.7495, -56.4352], [-12.9711, -38.5108], [11.3947, -69.6801], [-22.7825, -43.4286], [1.6704, -78.1399], [-29.9422, -50.9928], [10.4863, -66.8081], [-33.5947, -71.6075], [-8.0588, -48.475], [-20.5403, -47.4009], [8.0162, -62.4056], [-2.9006, -79.0045], [-7.077999999999999, -41.4678], [-5.795, -35.2094], [10.6427, -63.2555], [1.6825, -77.0725], [-22.4256, -45.4528], [-21.4758, -43.1241], [-27.3668, -70.3314], [4.3395, -61.7385], [-10.1675, -48.3277], [-36.827, -73.0498], [-26.6694, -57.1458], [-0.0984, -78.4531], [8.295, -62.7191], [-22.8833, -43.1036], [-33.5947, -71.6075]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_f0bc90e16c8ee860646fa1f7e0afbe53);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_da5ee0b193b3a97b1447ef6ea182ae1c.addTo(map_f0bc90e16c8ee860646fa1f7e0afbe53);
#
#
#             var layer_control_883c8bbe2ca5b26f0d6d5344c5c7bf81_layers = {
#                 base_layers : {
#                     &quot;cartodbdarkmatter&quot; : tile_layer_b016a4d6bb604f6887b543e92efb3c88,
#                 },
#                 overlays :  {
#                     &quot;macro_element_da5ee0b193b3a97b1447ef6ea182ae1c&quot; : fast_marker_cluster_da5ee0b193b3a97b1447ef6ea182ae1c,
#                 },
#             };
#             let layer_control_883c8bbe2ca5b26f0d6d5344c5c7bf81 = L.control.layers(
#                 layer_contr

# %%
# Importar bibliotecas para visualizar heatmap
from folium.plugins import HeatMap, HeatMapWithTime

# %%
# Seleciona apenas as colunas de latitude e longitude do dado
df = acled[['latitude', 'longitude']]
df.head()
# Out:
#    latitude  longitude
# 0   -8.0694   -37.2684
# 1   -3.1019   -60.0250
# 2    7.7872   -75.5331
# 3  -31.9745   -60.9160
# 4  -41.4693   -72.9424

# %%
# O método Heat Map do Folium aceita os dados em lista de pontos ou numpay arrays como latitude e longitude 
heat_data = list(df.values)
heat_data[:10]
# Out:
# [array([ -8.0694, -37.2684]),
#  array([ -3.1019, -60.025 ]),
#  array([  7.7872, -75.5331]),
#  array([-31.9745, -60.916 ]),
#  array([-41.4693, -72.9424]),
#  array([-19.7609, -44.3137]),
#  array([-22.0175, -47.8908]),
#  array([-18.8564, -41.9547]),
#  array([ 10.4829, -66.9036]),
#  array([ -7.3577, -35.7849])]

# %%
# Adicionar o map para o heat map no qual passamos a lista de numpy array
m = folium.Map([-23.6100596,-46.6973898], zoom_start=2, tiles='cartodbpositron')
HeatMap(heat_data).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_412a570dcf7193140e756caa72b33bd7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_412a570dcf7193140e756caa72b33bd7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_412a570dcf7193140e756caa72b33bd7 = L.map(
#                 &quot;map_412a570dcf7193140e756caa72b33bd7&quot;,
#                 {
#                     center: [-23.6100596, -46.6973898],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9feeb283e821ead4b532e30f42b867a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b9feeb283e821ead4b532e30f42b867a.addTo(map_412a570dcf7193140e756caa72b33bd7);
#
#
#             var heat_map_021f51b238c0039e28a443dbac05483c = L.heatLayer(
#                 [[-8.0694, -37.2684], [-3.1019, -60.025], [7.7872, -75.5331], [-31.9745, -60.916000000000004], [-41.4693, -72.9424], [-19.7609, -44.3137], [-22.0175, -47.8908], [-18.8564, -41.9547], [10.4829, -66.9036], [-7.3577, -35.7849], [10.0647, -69.357], [-10.1675, -48.3277], [10.4863, -66.8081], [8.5673, -74.5553], [-3.1019, -60.025], [-3.1019, -60.025], [-1.4558, -48.5044], [-12.2667, -38.9667], [-22.8569, -43.3008], [-5.1842, -37.3495], [8.889, -64.2527], [-15.6467, -56.1325], [-22.7642, -43.3994], [-36.827, -73.0498], [8.295, -62.7191], [-29.9533, -71.3395], [8.295, -62.7191], [-22.8569, -43.3008], [-3.1019, -60.025], [-7.2306, -35.8811], [-25.2637, -57.5759], [-25.3552, -57.4455], [-3.7172, -38.5431], [-37.8, -73.3833], [-22.8569, -43.3008], [-33.4569, -70.6483], [-9.7875, -54.91], [-3.5415, -45.607], [-9.9747, -67.81], [-29.9045, -71.2489], [-33.5142, -70.7651], [-22.8269, -43.0539], [-16.4071, -49.2194], [-9.4072, -36.6275], [3.4372, -76.5225], [10.4593, -74.8813], [-9.9747, -67.81], [11.3947, -69.6801], [-32.9264, -68.8473], [-26.624000000000002, -54.1111], [-25.7768, -49.3281], [4.6023, -61.1103], [-23.6524, -70.3954], [10.6427, -63.2555], [-23.8035, -45.4086], [10.4705, -68.0296], [-37.8, -73.3833], [-3.5083, -42.1925], [-33.3727, -69.1476], [-3.1019, -60.025], [-49.3282, -72.8894], [10.1182, -66.7751], [-25.2637, -57.5759], [8.295, -62.7191], [-33.7724, -69.0406], [-32.8983, -68.8431], [-6.4081, -38.8628], [-34.9777, -67.6895], [-33.192, -68.4623], [-22.
[-29.9045, -71.2489], [-32.6269, -62.6881], [-5.795, -35.2094], [-26.6694, -57.1458], [-33.4569, -70.6483], [-33.4311, -70.6045], [-13.8596, -40.082], [-18.0147, -70.2536], [-3.7172, -38.5431], [-12.2667, -38.9667], [-20.4428, -54.6464], [-1.3656, -48.3722], [-23.0067, -44.3181], [-15.8422, -70.0199], [-11.5189, -75.8994], [10.4829, -66.9036], [10.3917, -75.4824], [3.4372, -76.5225], [-22.5472, -55.7333], [-19.2178, -45.0014], [-20.2639, -40.42], [-3.1019, -60.025], [1.9345, -77.3062], [-35.6738, -64.9422], [-25.2637, -57.5759], [-35.6598, -63.7557], [-16.3989, -71.535], [-3.7172, -38.5431], [-23.6524, -70.3954], [-23.6524, -70.3954], [-38.1464, -65.9142], [-3.5443, -43.9148], [-36.827, -73.0498], [-35.0368, -64.2466], [-25.2637, -57.5759], [-36.8565, -63.6879], [8.2763, -73.8681], [-36.6205, -64.2899], [-28.4744, -65.7793], [-33.4569, -70.6483], [-3.7491, -73.2538], [-3.1019, -60.025], [0.0389, -51.0664], [-18.7878, -63.317], [-20.1421, -

# %% [markdown]
# ANIMAÇÃO

# %%
# Filtrar dados
df_2019 = acled[acled['year'] == 2019]

# %%
# Ler colunas específicas depois de filtrados 
df_2019_latlon = df_2019[['latitude', 'longitude', 'event_date']] #as primeiras são as coordenadas e a terceira é o "peso para a animação
df_2019_latlon.head()
# Out:
#    latitude  longitude        event_date
# 0   -8.0694   -37.2684  31 December 2019
# 1   -3.1019   -60.0250  31 December 2019
# 2    7.7872   -75.5331  31 December 2019
# 3  -31.9745   -60.9160  31 December 2019
# 4  -41.4693   -72.9424  31 December 2019

# %%
# Converter 'event_date' para função de tempo ('heat') 
df_2019_latlon['heat'] = pd.to_datetime(df_2019_latlon['event_date'])
df_2019_latlon.head()
# Out:
# C:\Users\iribarre\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    latitude  longitude        event_date       heat
# 0   -8.0694   -37.2684  31 December 2019 2019-12-31
# 1   -3.1019   -60.0250  31 December 2019 2019-12-31
# 2    7.7872   -75.5331  31 December 2019 2019-12-31
# 3  -31.9745   -60.9160  31 December 2019 2019-12-31
# 4  -41.4693   -72.9424  31 December 2019 2019-12-31

# %%
# extrair o número do mês que será usado como peso na animação
df_2019_latlon['month'] = df_2019_latlon['heat'].dt.month
# Out:
# C:\Users\iribarre\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Seleciona apenas os dados que serão usados
data = df_2019_latlon[['latitude', 'longitude', 'month']]
data.sample(10)
# Out:
#        latitude  longitude  month
# 8168   -22.8872   -42.0262      8
# 15896  -22.3848   -41.7832      4
# 3668   -17.3895   -66.1568     11
# 16539  -27.0524   -49.5188      3
# 5186   -11.0267   -68.7692     10
# 1170   -25.3468   -57.6065     12
# 4466   -34.9856   -71.2398     10
# 5773     7.3471   -61.8268     10
# 8280     8.2950   -62.7191      8
# 7960     4.6023   -61.1103      9

# %%
# Definir iterações sobre as linhas e então sobre o peso
heat_data = [[[row['latitude'],row['longitude']] for index, row in data[data['month'] == i].iterrows()] for i in range(0,13)]

# %%
# Passar heat data para o heat mapa usando o metodo de tempo como volume (?)
m = folium.Map([-23.6100596,-46.6973898], zoom_start=2, tiles='cartodbpositron')
HeatMapWithTime(heat_data, auto_play=True,max_opacity=0.8).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3120d19f95978a8e5fea0908a2be1623 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/pa7_hm.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/pa7_leaflet_hm.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
#
#             &lt;script&gt;
#                 var TDHeatmap = L.TimeDimension.Layer.extend({
#
#             initialize: function(data, options) {
#                 var heatmapCfg = {
#                     radius: 15,
#                     blur: 0.8,
#                     maxOpacity: 1.,
#                     scaleRadius: false,
#                     useLocalExtrema: false,
#                     latField: &#x27;lat&#x27;,
#                     lngField: &#x27;lng&#x27;,
#                     valueField: &#x27;count&#x27;,
#                     defaultWeight : 1,
#                 };
#                 heatmapCfg = $.extend({}, heatmapCfg, options.heatmapOptions || {});
#                 var layer = new HeatmapOverlay(heatmapCfg);
#                 L.TimeDimension.Layer.prototype.initialize.call(this, layer, options);
#                 this._currentLoadedTime = 0;
#                 this._currentTimeData = {
#                     data: []
#                     };
#                 this.data= data;
#                 this.defaultWeight = heatmapCfg.defaultWeight || 1;
#             },
#             onAdd: function(map) {
#                 L.TimeDimension.Layer.prototype.onAdd.call(this, map);
#                 map.addLayer(this._baseLayer);
#                 if (this._timeDimension) {
#                     this._getDataForTime(this._timeDimension.getCurrentTime());
#                 }
#             },
#             _onNewTimeLoading: function(ev) {
#                 this._getDataForTime(ev.time);
#                 return;
#             },
#             isReady: function(time) {
#                 return (this._currentLoadedTime == time);
#             },
#             _update: function() {
#                 this._baseLayer.setData(this._currentTimeData);
#                 return true;
#             },
#             _getDataForTime: function(time) {
#                     delete this._currentTimeData.data;
#                     this._currentTimeData.data = [];
#                     var data = this.data[time-1];
#                     for (var i = 0; i &lt; data.length; i++) {
#                         this._currentTimeData.data.push({
#                                 lat: data[i][0],
#                                 lng: data[i][1],
#                                 count: data[i].length&gt;2 ? data[i][2] : this.defaultWeight
#                             });
#                         }
#                     this._currentLoadedTime = time;
#                     if (this._timeDimension &amp;&amp; time == this._timeDimension.getCurrentTime() &amp;&amp; !this._timeDimension.isLoading()) {
#                         this._update();
#                     }
#                     this.fire(&#x27;timeload&#x27;, {
#                         time: time
#                     });
#                 }
#         });
#
#         L.Control.TimeDimensionCustom = L.Control.TimeDimension.extend({
#             initialize: function(index, options) {
#                 var playerOptions = {
#                     buffer: 1,
#                     minBufferReady: -1
#                     };
#                 options.playerOptions = $.extend({}, playerOptions, options.playerOptions || {});
#                 L.Control.TimeDimension.prototype.initialize.call(this, options);
#                 this.index = index;
#                 },
#             _getDisplayDateFormat: function(date){
#                 return this.index[date.getTime()-1];
#                 }
#             });
#             &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3120d19f95978a8e5fea0908a2be1623&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3120d19f95978a8e5fea0908a2be1623 = L.map(
#                 &quot;map_3120d19f95978a8e5fea0908a2be1623&quot;,
#                 {
#                     center: [-23.6100596, -46.6973898],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac690214ee6ed8005d688478ac3be678 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ac690214ee6ed8005d688478ac3be6
